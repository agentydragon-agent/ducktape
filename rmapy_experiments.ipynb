# %%
from rmapy.api import Client
client = Client()

import logging
logger = logging.getLogger('rmapy')
logging.basicConfig(level=logging.DEBUG)

# %%
# https://my.remarkable.com/device/desktop/connect
client.register_device("tcqapvwn")
# Out:
# True

# %%
client.renew_token()
assert client.is_auth()
client.get_meta_items()
# Out:
# DEBUG:rmapy:https://webapp-production-dot-remarkable-production.appspot.com/token/json/2/user/new
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): webapp-production-dot-remarkable-production.appspot.com:443
# DEBUG:urllib3.connectionpool:https://webapp-production-dot-remarkable-production.appspot.com:443 "POST /token/json/2/user/new HTTP/1.1" 200 None
# DEBUG:rmapy:https://document-storage-production-dot-remarkable-production.appspot.com/document-storage/json/2/docs
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): document-storage-production-dot-remarkable-production.appspot.com:443
# DEBUG:urllib3.connectionpool:https://document-storage-production-dot-remarkable-production.appspot.com:443 "GET /document-storage/json/2/docs HTTP/1.1" 500 323
# DEBUG:rmapy:
# <html><head>
# <meta http-equiv="content-type" content="text/html;charset=utf-8">
# <title>500 Server Error</title>
# </head>
# <body text=#000000 bgcolor=#ffffff>
# <h1>Error: Server Error</h1>
# <h2>The server encountered an error and could not complete your request.<p>Please try again in 30 seconds.</h2>
# <h2></h2>
# </body></html>
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_178682/863616111.py in <module>
#       1 client.renew_token()
#       2 assert client.is_auth()
# ----> 3 client.get_meta_items()
#
# ~/repos/rmapy/rmapy/api.py in get_meta_items(self)
#     185         log.debug(response.text)
#     186         if not response.ok:
# --> 187             raise Exception(f"Fetching meta items failed")
#     188         for item in response.json():
#     189             collection.add(item)
#
# Exception: Fetching meta items failed
